# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\minhthanh\.conda\envs\env\lib\site-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\minhthanh\.conda\envs\env\lib\site-packages (from pandas) (2.8.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\minhthanh\.conda\envs\env\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\minhthanh\.conda\envs\env\lib\site-packages (from pandas) (1.21.6)
# Requirement already satisfied: six>=1.5 in c:\users\minhthanh\.conda\envs\env\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.17.0)

# %%
import json
import pandas as pd
from kafka import KafkaProducer

def json_serializer(data):
    return json.dumps(data).encode('utf-8')

server = 'localhost:9092'

producer = KafkaProducer(
    bootstrap_servers=[server],
    value_serializer=json_serializer
)

producer.bootstrap_connected()
# Out:
# True

# %%
topic_name = 'green-trips'
df = pd.read_csv('data\green_tripdata_2019-10.csv')

# %%
from time import time

t0 = time()

for i in range(10, 1000):
    message = {'test_data': i, 'event_timestamp': time.time() * 1000}
    producer.send(topic_name, value=message)
    print(f"Sent: {message}")
    time.sleep(0.05)

producer.flush()

t1 = time()
took = t1 - t0
